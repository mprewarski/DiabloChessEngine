# %% [markdown]
# <a href="https://colab.research.google.com/github/mprewarski/DiabloChessEngine/blob/master/fin_sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install any dependencies

# %%
# !pip install -q yfinance
# !pip install -q datasets
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.3.1+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# gcsfs 2024.6.1 requires fsspec==2024.6.1, but you have fsspec 2024.5.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.

# %% [markdown]
# ## Import Libraries

# %%
# %matplotlib inline

import numpy as np
import polars as pl
import plotly.express as px
from datetime import datetime
import yfinance as yf
import matplotlib.pyplot as plt
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import datasets

# %%
dataset = datasets.load_dataset('ashraq/financial-news', split='train')
dataset
# Out:
# Downloading readme:   0%|          | 0.00/161 [00:00<?, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Downloading metadata:   0%|          | 0.00/809 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/143M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1845559 [00:00<?, ? examples/s]
# Dataset({
#     features: ['headline', 'url', 'publisher', 'date', 'stock'],
#     num_rows: 1845559
# })

# %%
df = dataset.to_polars()

# %%
df.head()
# Out:
# shape: (5, 5)
# ┌────────────────────────────┬───────────────────────────┬───────────┬─────────────────────┬───────┐
# │ headline                   ┆ url                       ┆ publisher ┆ date                ┆ stock │
# │ ---                        ┆ ---                       ┆ ---       ┆ ---                 ┆ ---   │
# │ str                        ┆ str                       ┆ str       ┆ str                 ┆ str   │
# ╞════════════════════════════╪═══════════════════════════╪═══════════╪═════════════════════╪═══════╡
# │ Agilent Technologies       ┆ http://www.gurufocus.com/ ┆ GuruFocus ┆ 2020-06-01 00:00:00 ┆ A     │
# │ Announces P…               ┆ news/11…                  ┆           ┆                     ┆       │
# │ Agilent (A) Gears Up for   ┆ http://www.zacks.com/stoc ┆ Zacks     ┆ 2020-05-18 00:00:00 ┆ A     │
# │ Q2 Earn…                   ┆ k/news/…                  ┆           ┆                     ┆       │
# │ J.P. Morgan Asset          ┆ http://www.gurufocus.com/ ┆ GuruFocus ┆ 2020-05-15 00:00:00 ┆ A     │
# │ Management Ann…            ┆ news/11…                  ┆           ┆                     ┆       │
# │ Pershing Square Capital    ┆ http://www.gurufocus.com/ ┆ GuruFocus ┆ 2020-05-15 00:00:00 ┆ A     │
# │ Manageme…                  ┆ news/11…                  ┆           ┆                     ┆       │
# │ Agilent Awards Trilogy     ┆ http://www.gurufocus.com/ ┆ GuruFocus ┆ 2020-05-12 00:00:00 ┆ A     │
# │ Sciences …                 ┆ news/11…                  ┆           ┆                     ┆       │
# └────────────────────────────┴───────────────────────────┴───────────┴─────────────────────┴───────┘

# %%
tickers = df["stock"].explode().unique().to_list()

# %%
'CPRT' in tickers
# Out:
# True

# %%
df_cprt = df.filter(pl.col("stock") == "CPRT")

# %%
df_cprt.shape
# Out:
# (594, 5)

# %%
model_name = "mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/933 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]

# %%
def calc_sentiment(model, tokenizer, text):
    inputs = tokenizer(text, return_tensors="pt", max_length=1022, truncation=True)
    outputs = model(**inputs)
    v = map_sf_to_single(outputs)
    return v
    #sentiment_class = outputs.logits.argmax(dim=1).item()
    #sentiment_mapping = {0: 'Negative', 1: 'Neutral', 2: 'Positive'}
    #predicted_sentiment = sentiment_mapping.get(sentiment_class, 'Unknown')

# %%
def map_sf_to_single(sf_out):
    smax = sf_out.logits.softmax(dim=1).squeeze()
    v = 1 * smax[2] + 0.5 * smax[1]
    return v.item()

# %%
def df_sentiment(df, col_name):
    #print(df['headline'].shape)
    sentiment = []
    for hl in df['headline']:
        s = calc_sentiment(model, tokenizer, hl)
        sentiment.append(s)
    return sentiment

# %%
sentiment = df_sentiment(df_cprt, 'headline')

# %%
df_cprt = df_cprt.with_columns(pl.Series(name="sentiment", values=sentiment))

# %%
df_cprt.head()
# Out:
# shape: (5, 6)
# ┌──────────────────────┬─────────────────────┬───────────┬─────────────────────┬───────┬───────────┐
# │ headline             ┆ url                 ┆ publisher ┆ date                ┆ stock ┆ sentiment │
# │ ---                  ┆ ---                 ┆ ---       ┆ ---                 ┆ ---   ┆ ---       │
# │ str                  ┆ str                 ┆ str       ┆ str                 ┆ str   ┆ f64       │
# ╞══════════════════════╪═════════════════════╪═══════════╪═════════════════════╪═══════╪═══════════╡
# │ SkyTop Capital       ┆ http://www.gurufocu ┆ GuruFocus ┆ 2020-05-15 00:00:00 ┆ CPRT  ┆ 0.499992  │
# │ Management LLC Bu…   ┆ s.com/news/11…      ┆           ┆                     ┆       ┆           │
# │ Gobi Capital Llc     ┆ http://www.gurufocu ┆ GuruFocus ┆ 2020-05-15 00:00:00 ┆ CPRT  ┆ 0.499987  │
# │ Buys Heico Corp…     ┆ s.com/news/11…      ┆           ┆                     ┆       ┆           │
# │ Foyston, Gordon, &   ┆ http://www.gurufocu ┆ GuruFocus ┆ 2020-05-15 00:00:00 ┆ CPRT  ┆ 0.499994  │
# │ Payne Inc Buy…       ┆ s.com/news/11…      ┆           ┆                     ┆       ┆           │
# │ Avenir Corp Buys     ┆ http://www.gurufocu ┆ GuruFocus ┆ 2020-05-14 00:00:00 ┆ CPRT  ┆ 0.499989  │
# │ Mastercard Inc,…     ┆ s.com/news/11…      ┆           ┆                     ┆       ┆           │
# │ Baird Financial      ┆ http://www.gurufocu ┆ GuruFocus ┆ 2020-05-14 00:00:00 ┆ CPRT  ┆ 0.49999   │
# │ Group, Inc. Buys…    ┆ s.com/news/11…      ┆           ┆                     ┆       ┆           │
# └──────────────────────┴─────────────────────┴───────────┴─────────────────────┴───────┴───────────┘

# %%
df_cprt = df_cprt.with_columns( pl.col("date").str.to_datetime(time_unit='ns'))

# %%
df_sorted = df_cprt.sort("date")

# %%
df_sorted.head(10)
# Out:
# shape: (10, 6)
# ┌─────────────────────┬────────────────────┬────────────────────┬──────────────┬───────┬───────────┐
# │ headline            ┆ url                ┆ publisher          ┆ date         ┆ stock ┆ sentiment │
# │ ---                 ┆ ---                ┆ ---                ┆ ---          ┆ ---   ┆ ---       │
# │ str                 ┆ str                ┆ str                ┆ datetime[ns] ┆ str   ┆ f64       │
# ╞═════════════════════╪════════════════════╪════════════════════╪══════════════╪═══════╪═══════════╡
# │ Bed, Bath & Beyond, ┆ https://www.benzin ┆ webmaster          ┆ 2010-09-22   ┆ CPRT  ┆ 0.499998  │
# │ Brocade On t…       ┆ ga.com/content…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Zacks #1 Rank       ┆ https://www.benzin ┆ webmaster          ┆ 2011-02-16   ┆ CPRT  ┆ 0.49999   │
# │ Additions for Wedn… ┆ ga.com/content…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Earnings Preview:   ┆ https://www.benzin ┆ Zacks              ┆ 2011-09-20   ┆ CPRT  ┆ 0.499992  │
# │ Copart - Analy…     ┆ ga.com/content…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Stocks Close Near   ┆ https://www.benzin ┆ Investor's         ┆ 2011-11-25   ┆ CPRT  ┆ 0.997131  │
# │ Lows Amid Lowe…     ┆ ga.com/content…    ┆ Business Daily     ┆ 00:00:00     ┆       ┆           │
# │ …                   ┆ …                  ┆ …                  ┆ …            ┆ …     ┆ …         │
# │ 8 Stocks Rising on  ┆ https://www.benzin ┆ webmaster          ┆ 2012-02-29   ┆ CPRT  ┆ 0.500029  │
# │ Monster Volum…      ┆ ga.com/content…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Copart Exceeds      ┆ http://www.zacks.c ┆ Zacks              ┆ 2012-02-29   ┆ CPRT  ┆ 0.500017  │
# │ Estimates - Analy…  ┆ om/stock/news/…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Zacks #1 Rank       ┆ http://www.zacks.c ┆ Zacks              ┆ 2012-03-06   ┆ CPRT  ┆ 0.499989  │
# │ Additions for Tues… ┆ om/stock/news/…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Auto Makers are Up; ┆ http://www.smallca ┆ Small Cap Network  ┆ 2012-03-13   ┆ CPRT  ┆ 0.500414  │
# │ How About Au…       ┆ pnetwork.com/A…    ┆                    ┆ 00:00:00     ┆       ┆           │
# └─────────────────────┴────────────────────┴────────────────────┴──────────────┴───────┴───────────┘

# %%
df_daily_avg = df_sorted.group_by_dynamic("date", every="1d").agg(pl.col("sentiment").mean())

# %%
df_sorted.head(10)
# Out:
# shape: (10, 6)
# ┌─────────────────────┬────────────────────┬────────────────────┬──────────────┬───────┬───────────┐
# │ headline            ┆ url                ┆ publisher          ┆ date         ┆ stock ┆ sentiment │
# │ ---                 ┆ ---                ┆ ---                ┆ ---          ┆ ---   ┆ ---       │
# │ str                 ┆ str                ┆ str                ┆ datetime[ns] ┆ str   ┆ f64       │
# ╞═════════════════════╪════════════════════╪════════════════════╪══════════════╪═══════╪═══════════╡
# │ Bed, Bath & Beyond, ┆ https://www.benzin ┆ webmaster          ┆ 2010-09-22   ┆ CPRT  ┆ 0.499998  │
# │ Brocade On t…       ┆ ga.com/content…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Zacks #1 Rank       ┆ https://www.benzin ┆ webmaster          ┆ 2011-02-16   ┆ CPRT  ┆ 0.49999   │
# │ Additions for Wedn… ┆ ga.com/content…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Earnings Preview:   ┆ https://www.benzin ┆ Zacks              ┆ 2011-09-20   ┆ CPRT  ┆ 0.499992  │
# │ Copart - Analy…     ┆ ga.com/content…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Stocks Close Near   ┆ https://www.benzin ┆ Investor's         ┆ 2011-11-25   ┆ CPRT  ┆ 0.997131  │
# │ Lows Amid Lowe…     ┆ ga.com/content…    ┆ Business Daily     ┆ 00:00:00     ┆       ┆           │
# │ …                   ┆ …                  ┆ …                  ┆ …            ┆ …     ┆ …         │
# │ 8 Stocks Rising on  ┆ https://www.benzin ┆ webmaster          ┆ 2012-02-29   ┆ CPRT  ┆ 0.500029  │
# │ Monster Volum…      ┆ ga.com/content…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Copart Exceeds      ┆ http://www.zacks.c ┆ Zacks              ┆ 2012-02-29   ┆ CPRT  ┆ 0.500017  │
# │ Estimates - Analy…  ┆ om/stock/news/…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Zacks #1 Rank       ┆ http://www.zacks.c ┆ Zacks              ┆ 2012-03-06   ┆ CPRT  ┆ 0.499989  │
# │ Additions for Tues… ┆ om/stock/news/…    ┆                    ┆ 00:00:00     ┆       ┆           │
# │ Auto Makers are Up; ┆ http://www.smallca ┆ Small Cap Network  ┆ 2012-03-13   ┆ CPRT  ┆ 0.500414  │
# │ How About Au…       ┆ pnetwork.com/A…    ┆                    ┆ 00:00:00     ┆       ┆           │
# └─────────────────────┴────────────────────┴────────────────────┴──────────────┴───────┴───────────┘

# %%
df_daily_avg.tail()
# Out:
# shape: (5, 2)
# ┌─────────────────────┬───────────┐
# │ date                ┆ sentiment │
# │ ---                 ┆ ---       │
# │ datetime[ns]        ┆ f64       │
# ╞═════════════════════╪═══════════╡
# │ 2020-05-04 00:00:00 ┆ 0.499987  │
# │ 2020-05-08 00:00:00 ┆ 0.499989  │
# │ 2020-05-13 00:00:00 ┆ 0.499991  │
# │ 2020-05-14 00:00:00 ┆ 0.499989  │
# │ 2020-05-15 00:00:00 ┆ 0.499991  │
# └─────────────────────┴───────────┘

# %%
import plotly.express as px

# %%
fig = px.bar(df_daily_avg, x="date", y="sentiment")
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py:105: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   v = v.dt.to_pydatetime()
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="74343caa-c32a-405d-8eae-6ae42fad99dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74343caa-c32a-405d-8eae-6ae42fad99dd")) {                    Plotly.newPlot(                        "74343caa-c32a-405d-8eae-6ae42fad99dd",                        [{"alignmentgroup":"True","hovertemplate":"date=%{x}\u003cbr\u003esentiment=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2010-09-22T00:00:00","2011-02-16T00:00:00","2011-09-20T00:00:00","2011-11-25T00:00:00","2011-12-09T00:00:00","2012-02-29T00:00:00","2012-03-06T00:00:00","2012-03-13T00:00:00","2012-03-16T00:00:00","2012-04-11T00:00:00","2012-04-13T00:00:00","2012-05-08T00:00:00","2012-05-10T00:00:00","2012-05-11T00:00:00","2012-05-24T00:00:00","2012-05-30T00:00:00","2012-06-01T00:00:00","2012-06-04T00:00:00","2012-06-05T00:00:00","2012-06-06T00:00:00","2012-06-08T00:00:00","2012-06-12T00:00:00","2012-06-13T00:00:00","2012-06-15T00:00:00","2012-09-24T00:00:00","2012-09-26T00:00:00","2012-10-19T00:00:00","2012-10-31T00:00:00","2012-11-14T00:00:00","2012-11-19T00:00:00","2012-11-27T00:00:00","2012-11-29T00:00:00","2012-12-03T00:00:00","2012-12-04T00:00:00","2012-12-20T00:00:00","2013-01-04T00:00:00","2013-01-07T00:00:00","2013-01-11T00:00:00","2013-01-31T00:00:00","2013-02-06T00:00:00","2013-02-23T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-18T00:00:00","2013-03-21T00:00:00","2013-04-24T00:00:00","2013-05-21T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-07-31T00:00:00","2013-09-25T00:00:00","2013-09-26T00:00:00","2013-09-30T00:00:00","2013-10-04T00:00:00","2013-11-08T00:00:00","2013-11-13T00:00:00","2013-11-21T00:00:00","2013-11-26T00:00:00","2014-02-12T00:00:00","2014-02-13T00:00:00","2014-02-26T00:00:00","2014-03-18T00:00:00","2014-04-29T00:00:00","2014-05-29T00:00:00","2014-07-18T00:00:00","2014-09-18T00:00:00","2014-09-22T00:00:00","2014-09-23T00:00:00","2014-09-25T00:00:00","2014-10-01T00:00:00","2014-10-05T00:00:00","2014-10-14T00:00:00","2014-10-15T00:00:00","2014-11-06T00:00:00","2014-11-25T00:00:00","2014-12-22T00:00:00","2015-01-09T00:00:00","2015-01-15T00:00:00","2015-02-09T00:00:00","2015-02-11T00:00:00","2015-02-19T00:00:00","2015-02-23T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-03-03T00:00:00","2015-03-13T00:00:00","2015-04-06T00:00:00","2015-05-19T00:00:00","2015-05-22T00:00:00","2015-05-26T00:00:00","2015-05-27T00:00:00","2015-05-28T00:00:00","2015-06-08T00:00:00","2015-06-10T00:00:00","2015-06-12T00:00:00","2015-06-15T00:00:00","2015-06-24T00:00:00","2015-07-14T00:00:00","2015-08-11T00:00:00","2015-09-10T00:00:00","2015-09-21T00:00:00","2015-09-22T00:00:00","2015-09-23T00:00:00","2015-10-14T00:00:00","2015-11-24T00:00:00","2015-11-27T00:00:00","2015-12-19T00:00:00","2015-12-30T00:00:00","2016-02-22T00:00:00","2016-02-23T00:00:00","2016-02-24T00:00:00","2016-03-09T00:00:00","2016-03-10T00:00:00","2016-03-31T00:00:00","2016-05-11T00:00:00","2016-05-13T00:00:00","2016-05-24T00:00:00","2016-05-25T00:00:00","2016-05-26T00:00:00","2016-06-03T00:00:00","2016-06-06T00:00:00","2016-06-09T00:00:00","2016-06-22T00:00:00","2016-06-24T00:00:00","2016-06-28T00:00:00","2016-07-26T00:00:00","2016-08-09T00:00:00","2016-08-14T00:00:00","2016-08-23T00:00:00","2016-09-19T00:00:00","2016-09-20T00:00:00","2016-09-21T00:00:00","2016-09-26T00:00:00","2016-09-30T00:00:00","2016-10-10T00:00:00","2016-10-15T00:00:00","2016-11-03T00:00:00","2016-11-15T00:00:00","2016-11-16T00:00:00","2016-11-21T00:00:00","2016-11-22T00:00:00","2016-12-05T00:00:00","2016-12- ...

# %%
# initialize parameters
start_date = datetime(2010, 9, 22)
end_date = datetime(2020, 5, 15)

# get the data
cprt_data = yf.download('CPRT', start = start_date,
                   end = end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
cprt_data.head()
# Out:
#                 Open      High      Low     Close  Adj Close    Volume
# Date
# 2010-09-22  2.252500  2.295625  2.24000  2.253750   2.253750   4363200
# 2010-09-23  2.009375  2.096875  1.95500  2.011875   2.011875  51760000
# 2010-09-24  2.036250  2.135625  2.03625  2.118750   2.118750  22403200
# 2010-09-27  2.119375  2.120625  2.09625  2.101250   2.101250   7737600
# 2010-09-28  2.112500  2.112500  2.04000  2.070625   2.070625  18347200

# %%
df_fin = pl.from_pandas(cprt_data, include_index=True)

# %%
df_fin.head()
# Out:
# shape: (5, 7)
# ┌─────────────────────┬──────────┬──────────┬─────────┬──────────┬───────────┬──────────┐
# │ Date                ┆ Open     ┆ High     ┆ Low     ┆ Close    ┆ Adj Close ┆ Volume   │
# │ ---                 ┆ ---      ┆ ---      ┆ ---     ┆ ---      ┆ ---       ┆ ---      │
# │ datetime[ns]        ┆ f64      ┆ f64      ┆ f64     ┆ f64      ┆ f64       ┆ i64      │
# ╞═════════════════════╪══════════╪══════════╪═════════╪══════════╪═══════════╪══════════╡
# │ 2010-09-22 00:00:00 ┆ 2.2525   ┆ 2.295625 ┆ 2.24    ┆ 2.25375  ┆ 2.25375   ┆ 4363200  │
# │ 2010-09-23 00:00:00 ┆ 2.009375 ┆ 2.096875 ┆ 1.955   ┆ 2.011875 ┆ 2.011875  ┆ 51760000 │
# │ 2010-09-24 00:00:00 ┆ 2.03625  ┆ 2.135625 ┆ 2.03625 ┆ 2.11875  ┆ 2.11875   ┆ 22403200 │
# │ 2010-09-27 00:00:00 ┆ 2.119375 ┆ 2.120625 ┆ 2.09625 ┆ 2.10125  ┆ 2.10125   ┆ 7737600  │
# │ 2010-09-28 00:00:00 ┆ 2.1125   ┆ 2.1125   ┆ 2.04    ┆ 2.070625 ┆ 2.070625  ┆ 18347200 │
# └─────────────────────┴──────────┴──────────┴─────────┴──────────┴───────────┴──────────┘

# %%
fig = px.line(df_fin, x="Date", y="Adj Close")
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3c152301-598b-4b28-9231-8567652c9bea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c152301-598b-4b28-9231-8567652c9bea")) {                    Plotly.newPlot(                        "3c152301-598b-4b28-9231-8567652c9bea",                        [{"hovertemplate":"Date=%{x}\u003cbr\u003eAdj Close=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2010-09-22T00:00:00","2010-09-23T00:00:00","2010-09-24T00:00:00","2010-09-27T00:00:00","2010-09-28T00:00:00","2010-09-29T00:00:00","2010-09-30T00:00:00","2010-10-01T00:00:00","2010-10-04T00:00:00","2010-10-05T00:00:00","2010-10-06T00:00:00","2010-10-07T00:00:00","2010-10-08T00:00:00","2010-10-11T00:00:00","2010-10-12T00:00:00","2010-10-13T00:00:00","2010-10-14T00:00:00","2010-10-15T00:00:00","2010-10-18T00:00:00","2010-10-19T00:00:00","2010-10-20T00:00:00","2010-10-21T00:00:00","2010-10-22T00:00:00","2010-10-25T00:00:00","2010-10-26T00:00:00","2010-10-27T00:00:00","2010-10-28T00:00:00","2010-10-29T00:00:00","2010-11-01T00:00:00","2010-11-02T00:00:00","2010-11-03T00:00:00","2010-11-04T00:00:00","2010-11-05T00:00:00","2010-11-08T00:00:00","2010-11-09T00:00:00","2010-11-10T00:00:00","2010-11-11T00:00:00","2010-11-12T00:00:00","2010-11-15T00:00:00","2010-11-16T00:00:00","2010-11-17T00:00:00","2010-11-18T00:00:00","2010-11-19T00:00:00","2010-11-22T00:00:00","2010-11-23T00:00:00","2010-11-24T00:00:00","2010-11-26T00:00:00","2010-11-29T00:00:00","2010-11-30T00:00:00","2010-12-01T00:00:00","2010-12-02T00:00:00","2010-12-03T00:00:00","2010-12-06T00:00:00","2010-12-07T00:00:00","2010-12-08T00:00:00","2010-12-09T00:00:00","2010-12-10T00:00:00","2010-12-13T00:00:00","2010-12-14T00:00:00","2010-12-15T00:00:00","2010-12-16T00:00:00","2010-12-17T00:00:00","2010-12-20T00:00:00","2010-12-21T00:00:00","2010-12-22T00:00:00","2010-12-23T00:00:00","2010-12-27T00:00:00","2010-12-28T00:00:00","2010-12-29T00:00:00","2010-12-30T00:00:00","2010-12-31T00:00:00","2011-01-03T00:00:00","2011-01-04T00:00:00","2011-01-05T00:00:00","2011-01-06T00:00:00","2011-01-07T00:00:00","2011-01-10T00:00:00","2011-01-11T00:00:00","2011-01-12T00:00:00","2011-01-13T00:00:00","2011-01-14T00:00:00","2011-01-18T00:00:00","2011-01-19T00:00:00","2011-01-20T00:00:00","2011-01-21T00:00:00","2011-01-24T00:00:00","2011-01-25T00:00:00","2011-01-26T00:00:00","2011-01-27T00:00:00","2011-01-28T00:00:00","2011-01-31T00:00:00","2011-02-01T00:00:00","2011-02-02T00:00:00","2011-02-03T00:00:00","2011-02-04T00:00:00","2011-02-07T00:00:00","2011-02-08T00:00:00","2011-02-09T00:00:00","2011-02-10T00:00:00","2011-02-11T00:00:00","2011-02-14T00:00:00","2011-02-15T00:00:00","2011-02-16T00:00:00","2011-02-17T00:00:00","2011-02-18T00:00:00","2011-02-22T00:00:00","2011-02-23T00:00:00","2011-02-24T00:00:00","2011-02-25T00:00:00","2011-02-28T00:00:00","2011-03-01T00:00:00","2011-03-02T00:00:00","2011-03-03T00:00:00","2011-03-04T00:00:00","2011-03-07T00:00:00","2011-03-08T00:00:00","2011-03-09T00:00:00","2011-03-10T00:00:00","2011-03-11T00:00:00","2011-03-14T00:00:00","2011-03-15T00:00:00","2011-03-16T00:00:00","2011-03-17T00:00:00","2011-03-18T00:00:00","2011-03-21T00:00:00","2011-03-22T00:00:00","2011-03-23T00:00:00","2011-03-24T00:00:00","2011-03-25T00:00:00","2011-03-28T00:00:00","2011-03-29T00:00:00","2011-03-30T00:00:00","2011-03-31T00:00:00","2011-04-01T00:00:00","2011-04-04T00:00:00","2011-04-05T00:00:00","2011-04-06T00:00:00","2011-04-07T00:00:00","2011-04-08T00:00:00","2011-04-11T00:00:00","2011-04-12T00:00:00","2011-04-13T00:00:00","2011-04-14T00:00:00","2011-04-15T00:00:00","2011-04-18T00:00:00","2011-04-19T ...

# %%
df_fin.head()
# Out:
# shape: (5, 7)
# ┌─────────────────────┬──────────┬──────────┬─────────┬──────────┬───────────┬──────────┐
# │ Date                ┆ Open     ┆ High     ┆ Low     ┆ Close    ┆ Adj Close ┆ Volume   │
# │ ---                 ┆ ---      ┆ ---      ┆ ---     ┆ ---      ┆ ---       ┆ ---      │
# │ datetime[ns]        ┆ f64      ┆ f64      ┆ f64     ┆ f64      ┆ f64       ┆ i64      │
# ╞═════════════════════╪══════════╪══════════╪═════════╪══════════╪═══════════╪══════════╡
# │ 2010-09-22 00:00:00 ┆ 2.2525   ┆ 2.295625 ┆ 2.24    ┆ 2.25375  ┆ 2.25375   ┆ 4363200  │
# │ 2010-09-23 00:00:00 ┆ 2.009375 ┆ 2.096875 ┆ 1.955   ┆ 2.011875 ┆ 2.011875  ┆ 51760000 │
# │ 2010-09-24 00:00:00 ┆ 2.03625  ┆ 2.135625 ┆ 2.03625 ┆ 2.11875  ┆ 2.11875   ┆ 22403200 │
# │ 2010-09-27 00:00:00 ┆ 2.119375 ┆ 2.120625 ┆ 2.09625 ┆ 2.10125  ┆ 2.10125   ┆ 7737600  │
# │ 2010-09-28 00:00:00 ┆ 2.1125   ┆ 2.1125   ┆ 2.04    ┆ 2.070625 ┆ 2.070625  ┆ 18347200 │
# └─────────────────────┴──────────┴──────────┴─────────┴──────────┴───────────┴──────────┘

# %%
df_daily_avg.head()
# Out:
# shape: (5, 2)
# ┌─────────────────────┬───────────┐
# │ date                ┆ sentiment │
# │ ---                 ┆ ---       │
# │ datetime[ns]        ┆ f64       │
# ╞═════════════════════╪═══════════╡
# │ 2010-09-22 00:00:00 ┆ 0.499998  │
# │ 2011-02-16 00:00:00 ┆ 0.49999   │
# │ 2011-09-20 00:00:00 ┆ 0.499992  │
# │ 2011-11-25 00:00:00 ┆ 0.997131  │
# │ 2011-12-09 00:00:00 ┆ 0.999416  │
# └─────────────────────┴───────────┘

# %%
df_join = df_fin.join(df_daily_avg, left_on="Date", right_on="date", how="left")

# %%
df_join.head()
# Out:
# shape: (5, 8)
# ┌──────────────┬──────────┬──────────┬─────────┬──────────┬───────────┬──────────┬───────────┐
# │ Date         ┆ Open     ┆ High     ┆ Low     ┆ Close    ┆ Adj Close ┆ Volume   ┆ sentiment │
# │ ---          ┆ ---      ┆ ---      ┆ ---     ┆ ---      ┆ ---       ┆ ---      ┆ ---       │
# │ datetime[ns] ┆ f64      ┆ f64      ┆ f64     ┆ f64      ┆ f64       ┆ i64      ┆ f64       │
# ╞══════════════╪══════════╪══════════╪═════════╪══════════╪═══════════╪══════════╪═══════════╡
# │ 2010-09-22   ┆ 2.2525   ┆ 2.295625 ┆ 2.24    ┆ 2.25375  ┆ 2.25375   ┆ 4363200  ┆ 0.499998  │
# │ 00:00:00     ┆          ┆          ┆         ┆          ┆           ┆          ┆           │
# │ 2010-09-23   ┆ 2.009375 ┆ 2.096875 ┆ 1.955   ┆ 2.011875 ┆ 2.011875  ┆ 51760000 ┆ null      │
# │ 00:00:00     ┆          ┆          ┆         ┆          ┆           ┆          ┆           │
# │ 2010-09-24   ┆ 2.03625  ┆ 2.135625 ┆ 2.03625 ┆ 2.11875  ┆ 2.11875   ┆ 22403200 ┆ null      │
# │ 00:00:00     ┆          ┆          ┆         ┆          ┆           ┆          ┆           │
# │ 2010-09-27   ┆ 2.119375 ┆ 2.120625 ┆ 2.09625 ┆ 2.10125  ┆ 2.10125   ┆ 7737600  ┆ null      │
# │ 00:00:00     ┆          ┆          ┆         ┆          ┆           ┆          ┆           │
# │ 2010-09-28   ┆ 2.1125   ┆ 2.1125   ┆ 2.04    ┆ 2.070625 ┆ 2.070625  ┆ 18347200 ┆ null      │
# │ 00:00:00     ┆          ┆          ┆         ┆          ┆           ┆          ┆           │
# └──────────────┴──────────┴──────────┴─────────┴──────────┴───────────┴──────────┴───────────┘

# %%
df_join = df_join.with_columns(pl.col("sentiment").fill_null(strategy="forward"))

# %%
close = pl.col("sentiment")
stuff = df_join.select(
    [
        pl.col("Date"),
        #close.alias("Raw"),
        close.rolling_mean(28).alias("28D MA"),
        close.alias("Expanding Average").cum_sum() / (close.cum_count() + 1),
        close.ewm_mean(alpha=0.01).alias("EWMA($\\alpha=.03$)"),
    ]
)

# %%
# Out:
# shape: (2_428, 4)
# ┌─────────────────────┬──────────┬───────────────────┬────────────────────┐
# │ Date                ┆ 28D MA   ┆ Expanding Average ┆ EWMA($\alpha=.03$) │
# │ ---                 ┆ ---      ┆ ---               ┆ ---                │
# │ datetime[ns]        ┆ f64      ┆ f64               ┆ f64                │
# ╞═════════════════════╪══════════╪═══════════════════╪════════════════════╡
# │ 2010-09-22 00:00:00 ┆ null     ┆ 0.499998          ┆ 0.499998           │
# │ 2010-09-23 00:00:00 ┆ null     ┆ 0.499998          ┆ 0.499998           │
# │ 2010-09-24 00:00:00 ┆ null     ┆ 0.499998          ┆ 0.499998           │
# │ 2010-09-27 00:00:00 ┆ null     ┆ 0.499998          ┆ 0.499998           │
# │ …                   ┆ …        ┆ …                 ┆ …                  │
# │ 2020-05-11 00:00:00 ┆ 0.813799 ┆ 0.612962          ┆ 0.698723           │
# │ 2020-05-12 00:00:00 ┆ 0.795956 ┆ 0.612916          ┆ 0.696736           │
# │ 2020-05-13 00:00:00 ┆ 0.778114 ┆ 0.612869          ┆ 0.694769           │
# │ 2020-05-14 00:00:00 ┆ 0.761152 ┆ 0.612823          ┆ 0.692821           │
# └─────────────────────┴──────────┴───────────────────┴────────────────────┘

# %%
max = df_join['Adj Close'].max()
df_join = df_join.with_columns(
    pl.col("Adj Close").truediv(max).alias("Norm Close")
)

# %%
close = pl.col("sentiment")
df_join.select(
    [
        pl.col("Date"),
        #close.alias("Raw"),
        close.rolling_mean(50).alias("50D MA"),
        #close.alias("Expanding Average").cum_sum() / (close.cum_count() + 1),
        close.ewm_mean(alpha=0.01).alias("EWMA($\\alpha=.01$)"),
        pl.col("Norm Close").alias("Norm Close"),
    ]
).to_pandas().set_index("Date").plot()
# Out:
# <Axes: xlabel='Date'>
